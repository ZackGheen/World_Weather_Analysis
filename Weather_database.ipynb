# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from citipy import citipy
import random
import time
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3112f5b1e446d0fa106b183bf6050091

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description})
                         

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 8 of Set 16 | ushuaia
# Processing Record 9 of Set 16 | panguna
# Processing Record 10 of Set 16 | severo-kurilsk
# Processing Record 11 of Set 16 | mataura
# Processing Record 12 of Set 16 | hilo
# Processing Record 13 of Set 16 | gourdon
# Processing Record 14 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 16 | wad madani
# Processing Record 16 of Set 16 | tuktoyaktuk
# Processing Record 17 of Set 16 | ambon
# Processing Record 18 of Set 16 | jamestown
# Processing Record 19 of Set 16 | yellowknife
# Processing Record 20 of Set 16 | hit
# Processing Record 21 of Set 16 | cape town
# Processing Record 22 of Set 16 | portland
# Processing Record 23 of Set 16 | cap malheureux
# Processing Record 24 of Set 16 | albany
# Processing Record 25 of Set 16 | tilichiki
# Processing Record 26 of Set 16 | rikitea
# Processing Record 27 of Set 16 | luderitz
# Processing Record 28 of Set 16 | ponta delgada
# Processing Record 29 of Set 16 | carsamba
# Processing Record 30 of Set 16 | nha trang
# Processing Record 31 of Set 16 | nikolskoye
# Processing Record 32 of Set 16 | hurricane
# Processing Record 33 of Set 16 | tasiilaq
# Processing Record 34 of Set 16 | hobart
# Processing Record 35 of Set 16 | koster
# Processing Record 36 of Set 16 | mao
# Processing Record 37 of Set 16 | sao filipe
# Processing Record 38 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 16 | atuona
# Processing Record 40 of Set 16 | kawalu
# Processing Record 41 of Set 16 | tiksi
# Processing Record 42 of Set 16 | diu
# Processing Record 43 of Set 16 | arraial do cabo
# Processing Record 44 of Set 16 | yambio
# Processing Record 45 of Set 16 | touros
# Processing Record 46 of Set 16 | ribeira grande
# Processing Record 47 of Set 16 | nanortalik
# Processing Record 48 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 16 | clyde river
# Processing Record 50 of Set 16 | grand centre
# City not found. Skipping...
# Processing Record 51 of Set 16 | saskylakh
# Processing Record 52 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 53 of Set 16 | ahuimanu
# Processing Record 54 of Set 16 | chapais
# Processing Record 55 of Set 16 | khatanga
# Processing Record 56 of Set 16 | sabha
# Processing Record 57 of Set 16 | palora
# Processing Record 1 of Set 17 | te anau
# Processing Record 2 of Set 17 | hermanus
# Processing Record 3 of Set 17 | bluff
# Processing Record 4 of Set 17 | bredasdorp
# Processing Record 5 of Set 17 | arcata
# Processing Record 6 of Set 17 | lloydminster
# Processing Record 7 of Set 17 | vestbygda
# City not found. Skipping...
# Processing Record 8 of Set 17 | rocha
# Processing Record 9 of Set 17 | murray bridge
# Processing Record 10 of Set 17 | matata
# Processing Record 11 of Set 17 | puerto ayora
# Processing Record 12 of Set 17 | lesogorsk
# Processing Record 13 of Set 17 | vaini
# Processing Record 14 of Set 17 | chilca
# Processing Record 15 of Set 17 | pangnirtung
# Processing Record 16 of Set 17 | port lincoln
# Processing Record 17 of Set 17 | yaan
# Processing Record 18 of Set 17 | kapaa
# Processing Record 19 of Set 17 | iranshahr
# Processing Record 20 of Set 17 | tautira
# Processing Record 21 of Set 17 | marslet
# Processing Record 22 of Set 17 | alekseyevskoye
# Processing Record 23 of Set 17 | riyadh
# Processing Record 24 of Set 17 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 17 | kavaratti
# Processing Record 26 of Set 17 | beloha
# Processing Record 27 of Set 17 | port alfred
# Processing Record 28 of Set 17 | dikson
# Processing Record 29 of Set 17 | lebu
# Processing Record 30 of Set 17 | busselton
# Processing Record 31 of Set 17 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 17 | lorengau
# Processing Record 33 of Set 17 | avarua
# Processing Record 34 of Set 17 | conceicao da barra
# Processing Record 35 of Set 17 | vina del mar
# Processing Record 36 of Set 17 | bethel
# Processing Record 37 of Set 17 | provideniya
# Processing Record 38 of Set 17 | badarpur
# Processing Record 39 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 17 | carnarvon
# Processing Record 41 of Set 17 | kayseri
# Processing Record 42 of Set 17 | cherskiy
# Processing Record 43 of Set 17 | suoyarvi
# Processing Record 44 of Set 17 | rangpur
# Processing Record 45 of Set 17 | mar del plata
# Processing Record 46 of Set 17 | cape girardeau
# Processing Record 47 of Set 17 | pitimbu
# Processing Record 48 of Set 17 | altay
# Processing Record 49 of Set 17 | nanfeng
# Processing Record 50 of Set 17 | kasama
# Processing Record 1 of Set 18 | kasongo
# Processing Record 2 of Set 18 | hithadhoo
# Processing Record 3 of Set 18 | east london
# Processing Record 4 of Set 18 | olafsvik
# Processing Record 5 of Set 18 | faanui
# Processing Record 6 of Set 18 | souillac
# Processing Record 7 of Set 18 | alghero
# Processing Record 8 of Set 18 | gualaceo
# Processing Record 9 of Set 18 | zilair
# Processing Record 10 of Set 18 | bengkulu
# Processing Record 11 of Set 18 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 18 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 18 | mahebourg
# Processing Record 14 of Set 18 | constitucion
# Processing Record 15 of Set 18 | chokurdakh
# Processing Record 16 of Set 18 | hagenow
# Processing Record 17 of Set 18 | barrow
# Processing Record 18 of Set 18 | leh
# Processing Record 19 of Set 18 | castro
# Processing Record 20 of Set 18 | karratha
# Processing Record 21 of Set 18 | mercedes
# Processing Record 22 of Set 18 | tuggurt
# City not found. Skipping...
# Processing Record 23 of Set 18 | semirom
# Processing Record 24 of Set 18 | nome
# Processing Record 25 of Set 18 | ilulissat
# Processing Record 26 of Set 18 | norman wells
# Processing Record 27 of Set 18 | cidreira
# Processing Record 28 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 18 | petrovsk-zabaykalskiy
# Processing Record 30 of Set 18 | mega
# Processing Record 31 of Set 18 | ormara
# Processing Record 32 of Set 18 | victoria
# Processing Record 33 of Set 18 | georgetown
# Processing Record 34 of Set 18 | saint-philippe
# Processing Record 35 of Set 18 | hanzhong
# Processing Record 36 of Set 18 | maniitsoq
# Processing Record 37 of Set 18 | pacific grove
# Processing Record 38 of Set 18 | bambous virieux
# Processing Record 39 of Set 18 | nsanje
# Processing Record 40 of Set 18 | los llanos de aridane
# Processing Record 41 of Set 18 | cloquet
# Processing Record 42 of Set 18 | havoysund
# Processing Record 43 of Set 18 | san patricio
# Processing Record 44 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 18 | buchanan
# Processing Record 46 of Set 18 | marrakesh
# Processing Record 47 of Set 18 | magistralnyy
# Processing Record 48 of Set 18 | taman
# Processing Record 49 of Set 18 | tungor
# Processing Record 50 of Set 18 | karaton
# Processing Record 1 of Set 19 | yerbogachen
# Processing Record 2 of Set 19 | wanning
# Processing Record 3 of Set 19 | limburg
# Processing Record 4 of Set 19 | saint george
# Processing Record 5 of Set 19 | caruray
# Processing Record 6 of Set 19 | vozhega
# Processing Record 7 of Set 19 | bathsheba
# Processing Record 8 of Set 19 | buala
# Processing Record 9 of Set 19 | statesboro
# Processing Record 10 of Set 19 | falealupo
# City not found. Skipping...
# Processing Record 11 of Set 19 | bossangoa
# Processing Record 12 of Set 19 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 19 | sri aman
# Processing Record 14 of Set 19 | bud
# Processing Record 15 of Set 19 | ponta do sol
# Processing Record 16 of Set 19 | svetlyy
# Processing Record 17 of Set 19 | vilcun
# Processing Record 18 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 19 | sun city west
# Processing Record 20 of Set 19 | manokwari
# Processing Record 21 of Set 19 | qaanaaq
# Processing Record 22 of Set 19 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 19 | praia da vitoria
# Processing Record 24 of Set 19 | la ronge
# Processing Record 25 of Set 19 | narsaq
# Processing Record 26 of Set 19 | damaturu
# Processing Record 27 of Set 19 | oxford
# Processing Record 28 of Set 19 | mitu
# Processing Record 29 of Set 19 | kruisfontein
# Processing Record 30 of Set 19 | avera
# Processing Record 31 of Set 19 | upernavik
# Processing Record 32 of Set 19 | juniyah
# City not found. Skipping...
# Processing Record 33 of Set 19 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 19 | riaba
# City not found. Skipping...
# Processing Record 35 of Set 19 | madison heights
# Processing Record 36 of Set 19 | mayor pablo lagerenza
# Processing Record 37 of Set 19 | dunedin
# Processing Record 38 of Set 19 | muroto
# Processing Record 39 of Set 19 | bramming
# Processing Record 40 of Set 19 | butaritari
# Processing Record 41 of Set 19 | tubruq
# City not found. Skipping...
# Processing Record 42 of Set 19 | paracuru
# Processing Record 43 of Set 19 | yarmouth
# Processing Record 44 of Set 19 | boa vista
# Processing Record 45 of Set 19 | timbiqui
# Processing Record 46 of Set 19 | bouza
# Processing Record 47 of Set 19 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 19 | harbour breton
# Processing Record 49 of Set 19 | maputo
# Processing Record 50 of Set 19 | zhigansk
# Processing Record 1 of Set 20 | hami
# Processing Record 2 of Set 20 | cayenne
# Processing Record 3 of Set 20 | zarubino
# Processing Record 4 of Set 20 | takoradi
# Processing Record 5 of Set 20 | kerman
# Processing Record 6 of Set 20 | new norfolk
# Processing Record 7 of Set 20 | punta arenas
# Processing Record 8 of Set 20 | syracuse
# Processing Record 9 of Set 20 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 10 of Set 20 | kavieng
# Processing Record 11 of Set 20 | hambantota
# Processing Record 12 of Set 20 | pontes e lacerda
# Processing Record 13 of Set 20 | thompson
# Processing Record 14 of Set 20 | bonthe
# Processing Record 15 of Set 20 | podgorodnyaya pokrovka
# Processing Record 16 of Set 20 | ulyanovsk
# Processing Record 17 of Set 20 | coquimbo
# Processing Record 18 of Set 20 | chuy
# Processing Record 19 of Set 20 | pangody
# Processing Record 20 of Set 20 | klaksvik
# Processing Record 21 of Set 20 | rio gallegos
# Processing Record 22 of Set 20 | margate
# Processing Record 23 of Set 20 | inderborskiy
# City not found. Skipping...
# Processing Record 24 of Set 20 | lexington
# Processing Record 25 of Set 20 | todos santos
# Processing Record 26 of Set 20 | abnub
# Processing Record 27 of Set 20 | vao
# Processing Record 28 of Set 20 | fortuna
# Processing Record 29 of Set 20 | lagoa
# Processing Record 30 of Set 20 | oranjemund
# Processing Record 31 of Set 20 | tupik
# Processing Record 32 of Set 20 | trinidad
# Processing Record 33 of Set 20 | hofn
# Processing Record 34 of Set 20 | husavik
# Processing Record 35 of Set 20 | charters towers
# Processing Record 36 of Set 20 | bouca
# Processing Record 37 of Set 20 | suntar
# Processing Record 38 of Set 20 | mahadday weyne
# City not found. Skipping...
# Processing Record 39 of Set 20 | kaitangata
# Processing Record 40 of Set 20 | yumen
# Processing Record 41 of Set 20 | vila velha
# Processing Record 42 of Set 20 | mulege
# Processing Record 43 of Set 20 | arua
# Processing Record 44 of Set 20 | lhokseumawe
# Processing Record 45 of Set 20 | mackay
# Processing Record 46 of Set 20 | brooks
# Processing Record 47 of Set 20 | belyy yar
# Processing Record 48 of Set 20 | eyl
# Processing Record 49 of Set 20 | arani
# Processing Record 50 of Set 20 | torbay
# Processing Record 1 of Set 21 | jiwani
# Processing Record 2 of Set 21 | villarrica
# Processing Record 3 of Set 21 | manuk mangkaw
# Processing Record 4 of Set 21 | cabo san lucas
# Processing Record 5 of Set 21 | balkanabat
# Processing Record 6 of Set 21 | pisco
# Processing Record 7 of Set 21 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 21 | port hedland
# Processing Record 9 of Set 21 | nuevo imperial
# Processing Record 10 of Set 21 | lima
# Processing Record 11 of Set 21 | jacqueville
# Processing Record 12 of Set 21 | bria
# Processing Record 13 of Set 21 | puksoozero
# Processing Record 14 of Set 21 | mumbwa
# Processing Record 15 of Set 21 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 21 | tiznit
# Processing Record 17 of Set 21 | genhe
# Processing Record 18 of Set 21 | yar-sale
# Processing Record 19 of Set 21 | esperance
# Processing Record 20 of Set 21 | opuwo
# Processing Record 21 of Set 21 | vanavara
# Processing Record 22 of Set 21 | fernley
# Processing Record 23 of Set 21 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 21 | ambanja
# Processing Record 25 of Set 21 | chute-aux-outardes
# Processing Record 26 of Set 21 | guerrero negro
# Processing Record 27 of Set 21 | burica
# City not found. Skipping...
# Processing Record 28 of Set 21 | iqaluit
# Processing Record 29 of Set 21 | punta umbria
# Processing Record 30 of Set 21 | egvekinot
# Processing Record 31 of Set 21 | san jeronimo
# Processing Record 32 of Set 21 | salalah
# Processing Record 33 of Set 21 | baragua
# Processing Record 34 of Set 21 | yanan
# City not found. Skipping...
# Processing Record 35 of Set 21 | hualmay
# Processing Record 36 of Set 21 | bandiagara
# Processing Record 37 of Set 21 | kahului
# Processing Record 38 of Set 21 | sitka
# Processing Record 39 of Set 21 | mastic beach
# Processing Record 40 of Set 21 | narasannapeta
# Processing Record 41 of Set 21 | yertsevo
# Processing Record 42 of Set 21 | padang
# Processing Record 43 of Set 21 | jutai
# Processing Record 44 of Set 21 | ucluelet
# Processing Record 45 of Set 21 | saint-joseph
# Processing Record 46 of Set 21 | broken hill
# Processing Record 47 of Set 21 | lleida
# Processing Record 48 of Set 21 | bow island
# Processing Record 49 of Set 21 | vostok
# Processing Record 50 of Set 21 | aykhal
# Processing Record 1 of Set 22 | svetlogorsk
# Processing Record 2 of Set 22 | sambava
# Processing Record 3 of Set 22 | sao francisco
# Processing Record 4 of Set 22 | katsuura
# Processing Record 5 of Set 22 | ha tinh
# Processing Record 6 of Set 22 | khash
# Processing Record 7 of Set 22 | niquero
# Processing Record 8 of Set 22 | fomeque
# Processing Record 9 of Set 22 | hasaki
# Processing Record 10 of Set 22 | ferme-neuve
# Processing Record 11 of Set 22 | saquarema
# Processing Record 12 of Set 22 | disraeli
# Processing Record 13 of Set 22 | pevek
# Processing Record 14 of Set 22 | sur
# Processing Record 15 of Set 22 | babstovo
# Processing Record 16 of Set 22 | berlevag
# Processing Record 17 of Set 22 | ipora
# Processing Record 18 of Set 22 | sayyan
# Processing Record 19 of Set 22 | baracoa
# Processing Record 20 of Set 22 | mount gambier
# Processing Record 21 of Set 22 | luanda
# Processing Record 22 of Set 22 | jumla
# Processing Record 23 of Set 22 | zyryanka
# Processing Record 24 of Set 22 | sorso
# Processing Record 25 of Set 22 | crixas
# Processing Record 26 of Set 22 | san cristobal
# Processing Record 27 of Set 22 | nelson bay
# Processing Record 28 of Set 22 | beringovskiy
# Processing Record 29 of Set 22 | santa maria
# Processing Record 30 of Set 22 | leningradskiy
# Processing Record 31 of Set 22 | sakakah
# Processing Record 32 of Set 22 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 22 | aklavik
# Processing Record 34 of Set 22 | loralai
# Processing Record 35 of Set 22 | gillette
# Processing Record 36 of Set 22 | visby
# Processing Record 37 of Set 22 | pontianak
# Processing Record 38 of Set 22 | loudi
# Processing Record 39 of Set 22 | sola
# Processing Record 40 of Set 22 | semibratovo
# Processing Record 41 of Set 22 | mandalgovi
# Processing Record 42 of Set 22 | longyearbyen
# Processing Record 43 of Set 22 | vardo
# Processing Record 44 of Set 22 | buenos aires
# Processing Record 45 of Set 22 | dvinskoy
# Processing Record 46 of Set 22 | nyurba
# Processing Record 47 of Set 22 | college
# Processing Record 48 of Set 22 | pocerski pricinovic
# Processing Record 49 of Set 22 | zuwarah
# Processing Record 50 of Set 22 | srednekolymsk
# Processing Record 1 of Set 23 | kandrian
# Processing Record 2 of Set 23 | atar
# Processing Record 3 of Set 23 | codrington
# Processing Record 4 of Set 23 | asosa
# Processing Record 5 of Set 23 | makakilo city
# Processing Record 6 of Set 23 | dryden
# Processing Record 7 of Set 23 | salto del guaira
# Processing Record 8 of Set 23 | hay river
# Processing Record 9 of Set 23 | catabola
# Processing Record 10 of Set 23 | gornyak
# Processing Record 11 of Set 23 | langsa
# Processing Record 12 of Set 23 | moerai
# Processing Record 13 of Set 23 | barra patuca
# Processing Record 14 of Set 23 | jiangkou
# Processing Record 15 of Set 23 | vacha
# Processing Record 16 of Set 23 | alappuzha
# Processing Record 17 of Set 23 | mahibadhoo
# Processing Record 18 of Set 23 | birjand
# Processing Record 19 of Set 23 | meulaboh
# Processing Record 20 of Set 23 | mezen
# Processing Record 21 of Set 23 | itoman
# Processing Record 22 of Set 23 | hattiesburg
# Processing Record 23 of Set 23 | havre-saint-pierre
# Processing Record 24 of Set 23 | mpika
# Processing Record 25 of Set 23 | caravelas
# Processing Record 26 of Set 23 | isangel
# Processing Record 27 of Set 23 | krasnoyarsk
# Processing Record 28 of Set 23 | fairbanks
# Processing Record 29 of Set 23 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 23 | biak
# Processing Record 31 of Set 23 | wattegama
# Processing Record 32 of Set 23 | kodiak
# Processing Record 33 of Set 23 | soyo
# Processing Record 34 of Set 23 | tawkar
# City not found. Skipping...
# Processing Record 35 of Set 23 | hovd
# Processing Record 36 of Set 23 | gornozavodsk
# Processing Record 37 of Set 23 | luau
# Processing Record 38 of Set 23 | kendari
# Processing Record 39 of Set 23 | cacapava do sul
# Processing Record 40 of Set 23 | aleksin
# Processing Record 41 of Set 23 | helong
# Processing Record 42 of Set 23 | zhanatas
# City not found. Skipping...
# Processing Record 43 of Set 23 | lodja
# Processing Record 44 of Set 23 | san quintin
# Processing Record 45 of Set 23 | manadhoo
# Processing Record 46 of Set 23 | camopi
# Processing Record 47 of Set 23 | la trinitaria
# Processing Record 48 of Set 23 | lethem
# Processing Record 49 of Set 23 | pangkalanbuun
# Processing Record 50 of Set 23 | alofi
# Processing Record 1 of Set 24 | acarau
# Processing Record 2 of Set 24 | diamantino
# Processing Record 3 of Set 24 | sorland
# Processing Record 4 of Set 24 | thinadhoo
# Processing Record 5 of Set 24 | tomatlan
# Processing Record 6 of Set 24 | shingu
# Processing Record 7 of Set 24 | golden
# Processing Record 8 of Set 24 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 24 | bago
# Processing Record 10 of Set 24 | tabas
# Processing Record 11 of Set 24 | copiapo
# Processing Record 12 of Set 24 | dhidhdhoo
# Processing Record 13 of Set 24 | marovoay
# Processing Record 14 of Set 24 | hamilton
# Processing Record 15 of Set 24 | sao joao da barra
# Processing Record 16 of Set 24 | socorro
# Processing Record 17 of Set 24 | pozo colorado
# Processing Record 18 of Set 24 | longlac
# City not found. Skipping...
# Processing Record 19 of Set 24 | mergui
# City not found. Skipping...
# Processing Record 20 of Set 24 | santa cruz
# Processing Record 21 of Set 24 | bereda
# Processing Record 22 of Set 24 | biloela
# Processing Record 23 of Set 24 | bermeo
# Processing Record 24 of Set 24 | kisac
# Processing Record 25 of Set 24 | vesyegonsk
# Processing Record 26 of Set 24 | goderich
# Processing Record 27 of Set 24 | tibiri
# Processing Record 28 of Set 24 | spring valley
# Processing Record 29 of Set 24 | faya
# Processing Record 30 of Set 24 | emba
# Processing Record 31 of Set 24 | quatre cocos
# Processing Record 32 of Set 24 | ukiah
# Processing Record 33 of Set 24 | bukachacha
# Processing Record 34 of Set 24 | kattivakkam
# Processing Record 35 of Set 24 | longyan
# Processing Record 36 of Set 24 | santa isabel do rio negro
# Processing Record 37 of Set 24 | asau
# Processing Record 38 of Set 24 | nishihara
# Processing Record 39 of Set 24 | tuatapere
# Processing Record 40 of Set 24 | sao sebastiao
# Processing Record 41 of Set 24 | natal
# Processing Record 42 of Set 24 | kieta
# Processing Record 43 of Set 24 | cockburn town
# Processing Record 44 of Set 24 | cairns
# Processing Record 45 of Set 24 | kamina
# Processing Record 46 of Set 24 | ternate
# Processing Record 47 of Set 24 | magoula
# Processing Record 48 of Set 24 | hokitika
# Processing Record 49 of Set 24 | emerald
# Processing Record 50 of Set 24 | osa
# Processing Record 1 of Set 25 | gushikawa
# Processing Record 2 of Set 25 | bontang
# Processing Record 3 of Set 25 | outjo
# Processing Record 4 of Set 25 | shangrao
# Processing Record 5 of Set 25 | kirakira
# Processing Record 6 of Set 25 | djambala
# Processing Record 7 of Set 25 | lambare
# Processing Record 8 of Set 25 | uruacu
# Processing Record 9 of Set 25 | shimoda
# Processing Record 10 of Set 25 | warri
# Processing Record 11 of Set 25 | deputatskiy
# Processing Record 12 of Set 25 | erdenet
# Processing Record 13 of Set 25 | gouyave
# Processing Record 14 of Set 25 | brae
# Processing Record 15 of Set 25 | malindi
# Processing Record 16 of Set 25 | tokur
# Processing Record 17 of Set 25 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 25 | rae bareli
# Processing Record 19 of Set 25 | lavrentiya
# Processing Record 20 of Set 25 | mackenzie
# Processing Record 21 of Set 25 | notre-dame-du-lac
# Processing Record 22 of Set 25 | rio branco
# Processing Record 23 of Set 25 | naze
# Processing Record 24 of Set 25 | seoul
# Processing Record 25 of Set 25 | gulshat
# City not found. Skipping...
# Processing Record 26 of Set 25 | qixingtai
# Processing Record 27 of Set 25 | armacao dos buzios
# City not found. Skipping...
# Processing Record 28 of Set 25 | rio grande
# Processing Record 29 of Set 25 | saldanha
# Processing Record 30 of Set 25 | bushehr
# Processing Record 31 of Set 25 | hrubieszow
# Processing Record 32 of Set 25 | udachnyy
# Processing Record 33 of Set 25 | arkansas city
# Processing Record 34 of Set 25 | hervey bay
# Processing Record 35 of Set 25 | port elizabeth
# Processing Record 36 of Set 25 | gwadar
# Processing Record 37 of Set 25 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 25 | bafra
# Processing Record 39 of Set 25 | axim
# Processing Record 40 of Set 25 | samut prakan
# Processing Record 41 of Set 25 | carbonia
# Processing Record 42 of Set 25 | fort saint james
# Processing Record 43 of Set 25 | paamiut
# Processing Record 44 of Set 25 | trogir
# Processing Record 45 of Set 25 | marystown
# Processing Record 46 of Set 25 | maneadero
# Processing Record 47 of Set 25 | port blair
# Processing Record 48 of Set 25 | kompaniyivka
# Processing Record 49 of Set 25 | floro
# Processing Record 50 of Set 25 | lompoc
# Processing Record 1 of Set 26 | finspang
# Processing Record 2 of Set 26 | yulara
# Processing Record 3 of Set 26 | anloga
# Processing Record 4 of Set 26 | general roca
# Processing Record 5 of Set 26 | morgan city
# Processing Record 6 of Set 26 | ravar
# Processing Record 7 of Set 26 | inhambane
# Processing Record 8 of Set 26 | palmer
# Processing Record 9 of Set 26 | port-gentil
# Processing Record 10 of Set 26 | mosquera
# Processing Record 11 of Set 26 | oron
# Processing Record 12 of Set 26 | ahipara
# Processing Record 13 of Set 26 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 26 | valdivia
# Processing Record 15 of Set 26 | niquelandia
# Processing Record 16 of Set 26 | senneterre
# Processing Record 17 of Set 26 | port hardy
# Processing Record 18 of Set 26 | cam ranh
# Processing Record 19 of Set 26 | northam
# Processing Record 20 of Set 26 | koungou
# Processing Record 21 of Set 26 | zlatoustovsk
# City not found. Skipping...
# Processing Record 22 of Set 26 | namibe
# Processing Record 23 of Set 26 | mareeba
# Processing Record 24 of Set 26 | sakaiminato
# Processing Record 25 of Set 26 | altea
# Processing Record 26 of Set 26 | cuamba
# Processing Record 27 of Set 26 | nioro
# Processing Record 28 of Set 26 | airai
# Processing Record 29 of Set 26 | datong
# Processing Record 30 of Set 26 | tarudant
# City not found. Skipping...
# Processing Record 31 of Set 26 | chama
# Processing Record 32 of Set 26 | belmonte
# Processing Record 33 of Set 26 | baie-saint-paul
# Processing Record 34 of Set 26 | west wendover
# Processing Record 35 of Set 26 | alyangula
# Processing Record 36 of Set 26 | methven
# Processing Record 37 of Set 26 | santo tomas
# Processing Record 38 of Set 26 | tagusao
# Processing Record 39 of Set 26 | davila
# Processing Record 40 of Set 26 | veinticinco de mayo
# Processing Record 41 of Set 26 | tiarei
# Processing Record 42 of Set 26 | whitehorse
# Processing Record 43 of Set 26 | jiuquan
# Processing Record 44 of Set 26 | ulaanbaatar
# Processing Record 45 of Set 26 | petatlan
# Processing Record 46 of Set 26 | san carlos de bariloche
# Processing Record 47 of Set 26 | talnakh
# Processing Record 48 of Set 26 | hollola
# Processing Record 49 of Set 26 | taltal
# Processing Record 50 of Set 26 | nemuro
# Processing Record 1 of Set 27 | henties bay
# Processing Record 2 of Set 27 | santa adelia
# Processing Record 3 of Set 27 | north bend
# Processing Record 4 of Set 27 | chodavaram
# Processing Record 5 of Set 27 | alta floresta
# Processing Record 6 of Set 27 | mecca
# Processing Record 7 of Set 27 | belaya gora
# Processing Record 8 of Set 27 | sechura
# Processing Record 9 of Set 27 | milingimbi
# City not found. Skipping...
# Processing Record 10 of Set 27 | leshukonskoye
# Processing Record 11 of Set 27 | plainview
# Processing Record 12 of Set 27 | wa
# City not found. Skipping...
# Processing Record 13 of Set 27 | davidson
# Processing Record 14 of Set 27 | hobyo
# Processing Record 15 of Set 27 | alice springs
# Processing Record 16 of Set 27 | eureka
# Processing Record 17 of Set 27 | pochutla
# Processing Record 18 of Set 27 | eucaliptus
# Processing Record 19 of Set 27 | veraval
# Processing Record 20 of Set 27 | saint-pierre
# Processing Record 21 of Set 27 | san manuel
# Processing Record 22 of Set 27 | lubango
# Processing Record 23 of Set 27 | ostrovnoy
# Processing Record 24 of Set 27 | vila do maio
# Processing Record 25 of Set 27 | jinji
# Processing Record 26 of Set 27 | banda aceh
# Processing Record 27 of Set 27 | jinchang
# Processing Record 28 of Set 27 | neuquen
# Processing Record 29 of Set 27 | dingle
# Processing Record 30 of Set 27 | aljezur
# Processing Record 31 of Set 27 | eltham
# Processing Record 32 of Set 27 | vredendal
# Processing Record 33 of Set 27 | kununurra
# Processing Record 34 of Set 27 | moose factory
# Processing Record 35 of Set 27 | jinan
# Processing Record 36 of Set 27 | bestobe
# Processing Record 37 of Set 27 | san felipe
# Processing Record 38 of Set 27 | praya
# Processing Record 39 of Set 27 | lashio
# Processing Record 40 of Set 27 | calamar
# Processing Record 41 of Set 27 | provost
# Processing Record 42 of Set 27 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 27 | el faiyum
# City not found. Skipping...
# Processing Record 44 of Set 27 | laguna de duero
# Processing Record 45 of Set 27 | dzaoudzi
# Processing Record 46 of Set 27 | howard springs
# Processing Record 47 of Set 27 | villa maria
# Processing Record 48 of Set 27 | jiayuguan
# Processing Record 49 of Set 27 | bethal
# Processing Record 50 of Set 27 | kegayli
# City not found. Skipping...
# Processing Record 1 of Set 28 | mount isa
# Processing Record 2 of Set 28 | gigmoto
# Processing Record 3 of Set 28 | bareli
# Processing Record 4 of Set 28 | muros
# Processing Record 5 of Set 28 | sinjah
# City not found. Skipping...
# Processing Record 6 of Set 28 | taree
# Processing Record 7 of Set 28 | saravan
# Processing Record 8 of Set 28 | ayan
# Processing Record 9 of Set 28 | komsomolskiy
# Processing Record 10 of Set 28 | jinchengjiang
# City not found. Skipping...
# Processing Record 11 of Set 28 | solwezi
# Processing Record 12 of Set 28 | svirstroy
# Processing Record 13 of Set 28 | mari-turek
# Processing Record 14 of Set 28 | eganville
# Processing Record 15 of Set 28 | xixiang
# Processing Record 16 of Set 28 | beitbridge
# Processing Record 17 of Set 28 | casma
# Processing Record 18 of Set 28 | mayumba
# Processing Record 19 of Set 28 | solenzo
# Processing Record 20 of Set 28 | alugan
# Processing Record 21 of Set 28 | andenes
# Processing Record 22 of Set 28 | reconquista
# Processing Record 23 of Set 28 | ajdabiya
# Processing Record 24 of Set 28 | aleksandrov gay
# Processing Record 25 of Set 28 | satipo
# Processing Record 26 of Set 28 | ballina
# Processing Record 27 of Set 28 | ivanishchi
# Processing Record 28 of Set 28 | tanete
# Processing Record 29 of Set 28 | morondava
# Processing Record 30 of Set 28 | burnie
# Processing Record 31 of Set 28 | ancud
# Processing Record 32 of Set 28 | svetlaya
# Processing Record 33 of Set 28 | mattru
# Processing Record 34 of Set 28 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 28 | kefamenanu
# Processing Record 36 of Set 28 | skjaerhollen
# City not found. Skipping...
# Processing Record 37 of Set 28 | santa rosa
# Processing Record 38 of Set 28 | krasnoselkup
# Processing Record 39 of Set 28 | itaituba
# Processing Record 40 of Set 28 | kartuzy
# Processing Record 41 of Set 28 | erenhot
# Processing Record 42 of Set 28 | awbari
# Processing Record 43 of Set 28 | lerwick
# Processing Record 44 of Set 28 | mushie
# Processing Record 45 of Set 28 | groningen
# Processing Record 46 of Set 28 | karwar
# Processing Record 47 of Set 28 | port augusta
# Processing Record 48 of Set 28 | irpa irpa
# Processing Record 49 of Set 28 | toora-khem
# Processing Record 50 of Set 28 | raymondville
# Processing Record 1 of Set 29 | agustin codazzi
# Processing Record 2 of Set 29 | lasa
# Processing Record 3 of Set 29 | ibague
# Processing Record 4 of Set 29 | nampa
# Processing Record 5 of Set 29 | amazar
# Processing Record 6 of Set 29 | bonavista
# Processing Record 7 of Set 29 | mabilo
# City not found. Skipping...
# Processing Record 8 of Set 29 | pachora
# Processing Record 9 of Set 29 | ayorou
# Processing Record 10 of Set 29 | broome
# Processing Record 11 of Set 29 | jalu
# Processing Record 12 of Set 29 | dzhebariki-khaya
# Processing Record 13 of Set 29 | ngunguru
# Processing Record 14 of Set 29 | sylva
# Processing Record 15 of Set 29 | grindavik
# Processing Record 16 of Set 29 | mayskiy
# Processing Record 17 of Set 29 | phuket
# Processing Record 18 of Set 29 | geraldton
# Processing Record 19 of Set 29 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 29 | izhma
# Processing Record 21 of Set 29 | salamiyah
# Processing Record 22 of Set 29 | vrangel
# Processing Record 23 of Set 29 | valparaiso
# Processing Record 24 of Set 29 | sisimiut
# Processing Record 25 of Set 29 | southbridge
# Processing Record 26 of Set 29 | kanniyakumari
# Processing Record 27 of Set 29 | nanchang
# Processing Record 28 of Set 29 | ladario
# Processing Record 29 of Set 29 | zlitan
# Processing Record 30 of Set 29 | neyshabur
# Processing Record 31 of Set 29 | san rafael del sur
# Processing Record 32 of Set 29 | znamenskoye
# Processing Record 33 of Set 29 | narok
# Processing Record 34 of Set 29 | cap-aux-meules
# Processing Record 35 of Set 29 | pierre
# Processing Record 36 of Set 29 | elban
# Processing Record 37 of Set 29 | bandarbeyla
# Processing Record 38 of Set 29 | westport
# Processing Record 39 of Set 29 | temaraia
# City not found. Skipping...
# Processing Record 40 of Set 29 | zhanaozen
# Processing Record 41 of Set 29 | kamenka
# Processing Record 42 of Set 29 | richards bay
# Processing Record 43 of Set 29 | hueyapan
# Processing Record 44 of Set 29 | inirida
# Processing Record 45 of Set 29 | goulburn
# Processing Record 46 of Set 29 | havelock
# Processing Record 47 of Set 29 | tocopilla
# Processing Record 48 of Set 29 | verkhnevilyuysk
# Processing Record 49 of Set 29 | bridgetown
# Processing Record 50 of Set 29 | umm lajj
# Processing Record 1 of Set 30 | redlands
# Processing Record 2 of Set 30 | fuling
# Processing Record 3 of Set 30 | pafos
# Processing Record 4 of Set 30 | adamovka
# Processing Record 5 of Set 30 | krasnyy chikoy
# Processing Record 6 of Set 30 | jawa
# Processing Record 7 of Set 30 | newport
# Processing Record 8 of Set 30 | carutapera
# Processing Record 9 of Set 30 | sioux lookout
# Processing Record 10 of Set 30 | fairmont
# Processing Record 11 of Set 30 | bom jesus
# Processing Record 12 of Set 30 | khingansk
# Processing Record 13 of Set 30 | shelburne
# Processing Record 14 of Set 30 | iquique
# Processing Record 15 of Set 30 | kidal
# Processing Record 16 of Set 30 | lang suan
# Processing Record 17 of Set 30 | ginda
# Processing Record 18 of Set 30 | bosaso
# Processing Record 19 of Set 30 | bregenz
# Processing Record 20 of Set 30 | gorontalo
# Processing Record 21 of Set 30 | kharan
# Processing Record 22 of Set 30 | lodwar
# Processing Record 23 of Set 30 | talcahuano
# Processing Record 24 of Set 30 | rognan
# Processing Record 25 of Set 30 | japura
# Processing Record 26 of Set 30 | flinders
# Processing Record 27 of Set 30 | rauma
# Processing Record 28 of Set 30 | marawi
# Processing Record 29 of Set 30 | adrar
# Processing Record 30 of Set 30 | azar shahr
# City not found. Skipping...
# Processing Record 31 of Set 30 | pangoa
# Processing Record 32 of Set 30 | harper
# Processing Record 33 of Set 30 | huarmey
# Processing Record 34 of Set 30 | zorya
# Processing Record 35 of Set 30 | poya
# Processing Record 36 of Set 30 | muhos
# Processing Record 37 of Set 30 | vestmannaeyjar
# Processing Record 38 of Set 30 | poronaysk
# Processing Record 39 of Set 30 | chateau-thierry
# Processing Record 40 of Set 30 | kodinsk
# Processing Record 41 of Set 30 | batavia
# Processing Record 42 of Set 30 | korla
# Processing Record 43 of Set 30 | marcali
# Processing Record 44 of Set 30 | makungu
# Processing Record 45 of Set 30 | vwawa
# Processing Record 46 of Set 30 | vila franca do campo
# Processing Record 47 of Set 30 | marzuq
# Processing Record 48 of Set 30 | severo-yeniseyskiy
# Processing Record 49 of Set 30 | umm kaddadah
# Processing Record 50 of Set 30 | harsud
# Processing Record 1 of Set 31 | thabazimbi
# Processing Record 2 of Set 31 | terenos
# Processing Record 3 of Set 31 | chapar
# Processing Record 4 of Set 31 | la gloria
# Processing Record 5 of Set 31 | uwajima
# Processing Record 6 of Set 31 | camana
# Processing Record 7 of Set 31 | anuchino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 700

# %%
Weather_Database = pd.DataFrame(city_data)
Weather_Database.head(20)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia      AR -54.8000  -68.3000     62.26        48          20
# 1          Panguna      PG  -6.3164  155.4848     69.31        85          85
# 2   Severo-Kurilsk      RU  50.6789  156.1250     34.86        86         100
# 3          Mataura      NZ -46.1927  168.8643     44.47        74          37
# 4             Hilo      US  19.7297 -155.0900     71.80        43          90
# 5          Gourdon      FR  44.7500    1.5000     38.25        94          97
# 6       Wad Madani      SD  14.4012   33.5199     84.81        23           0
# 7      Tuktoyaktuk      CA  69.4541 -133.0374     -7.60        77          75
# 8            Ambon      ID  -3.6954  128.1814     81.57        80          99
# 9        Jamestown      US  42.0970  -79.2353     63.52        81          90
# 10     Yellowknife      CA  62.4560 -114.3525     -3.59        88          75
# 11             Hit      IQ  33.6416   42.8251     56.28        39          25
# 12       Cape Town      ZA -33.9258   18.4232     70.09        62          20
# 13        Portland      US  45.5234 -122.6762     48.43        92          90
# 14  Cap Malheureux      MU -19.9842   57.6142     79.47        70         100
# 15          Albany      US  42.6001  -73.9662     56.32        93         100
# 16       Tilichiki      RU  60.4667  166.1000    -13.63        82           3
# 17         Rikitea      PF -23.1203 -134.9692     75.43        75         100
# 18        Luderitz      NA -26.6481   15.1594     63.99        78           0
# 19   Ponta Delgada      PT  37.7333  -25.6667     66.92        77          40
#
#     Wind Speed Weather Description
# 0         9.22          few clouds
# 1         1.72     overcast clouds
# 2        24.09     overcast clouds
# 3         1.48    scattered clouds
# 4        11.50          light rain
# 5         1.28     overcast clouds
# 6        10.54           clear sky
# 7         8.05       broken clouds
# 8         6.55       moderate rain
# 9        14.00     overcast clouds
# 10       17.27       broken clouds
# 11        5.61    scattered clouds
# 12        3.00          few clouds
# 13        4.00       moderate rain
# 14        7.00          light rain
# 15        1.01     overcast clouds
# 16        9.24           clear sky
# 17       14.81     overcast clouds
# 18       14.32           clear sky
# 19       14.97    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the data into a CSV.
Weather_Database.to_csv(output_data_file, index_label="City_ID")
